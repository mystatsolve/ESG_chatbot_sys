# %%
#가상환경 nlp1
#https://www.datascienceengineer.com/blog/post-multiple-pdfs-with-gpt
###참고 https://github.com/sudarshan-koirala/youtube-stuffs/blob/main/langchain/Chat_with_Any_Documents_Own_ChatGPT_with_LangChain.ipynb
from langchain_community.document_loaders import PyPDFLoader

# %%
import os

# %%
import openai
from langchain_openai import OpenAI

# %%
import getpass

os.environ["OPENAI_API_KEY"] = "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"

# %%
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import ElasticVectorSearch, Pinecone, Weaviate, FAISS
from langchain.document_loaders import PyPDFLoader
from langchain.vectorstores import Chroma
from langchain.chat_models import ChatOpenAI
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.chains import RetrievalQA, ConversationalRetrievalChain

# %%
from tqdm import tqdm

# %%
loader = PyPDFLoader("C:/Users/user/Desktop/LLM/PDFs/2022 신세계 ESG 보고서.pdf")

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
pages = loader.load_and_split(text_splitter)

# %%
directory = 'index_store'
vector_index = Chroma.from_documents(pages, OpenAIEmbeddings(), persist_directory=directory)
vector_index.persist() # actually the Chroma client automatically persists the indexes when it is disposed - however better save then sorry :-)
# Out:
# c:\Users\user\anaconda3\envs\nlp1\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.1.0 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
#loader = PyPDFLoader("C:/Users/user/Desktop/LLM/PDFs/2022 한국지역난방공사 ESG보고서.pdf")
#pages_new = loader.load_and_split(text_splitter)
#_ = vector_index.add_documents(pages_new)
#vector_index.persist()

# %%
foler_path = "C:/Users/user/Desktop/LLM/PDFs" #-- 파일이 저장된 폴더 경로
folderlist = os.listdir(foler_path)

# %%
folderlist
# Out:
# ['2022 (주)LG생활건강 ESG 보고서.pdf',
#  '2022 미래에셋생명 지속가능경영보고서.pdf',
#  '2022 신세계 ESG 보고서.pdf',
#  '2022 한국지역난방공사 ESG보고서.pdf',
#  '2022-2023_LG전자 지속가능경영보고서_FACT BOOK.pdf',
#  '2022_LGChem_Sustainability_Report_KOR.pdf',
#  '2022년 (주)두산 ESG 보고서_국문.pdf',
#  '2023 SK주식회사 지속가능경영보고서.pdf',
#  '2023 금호타이어 지속가능경영보고서.pdf',
#  '2023 기아 지속가능경영보고서.pdf',
#  '2023 한진칼 ESG 보고서.pdf',
#  '2023 현대건설 지속가능경영보고서_국문.pdf',
#  '2023년 현대차 지속가능성보고서.pdf',
#  'emart 2022 Sustainability Report.pdf',
#  'IBK 2023 지속가능경영보고서.pdf',
#  'LG ESG Reporting 2022-2023_Korean.pdf',
#  'LG디스플레이 2023 ESG Report.pdf',
#  'LG에너지솔루션_2022 ESG Report_(KOR).pdf',
#  '[GS리테일] 지속가능경영보고서 등 관련사항(자율공시) 기타공개첨부서류 (2023.07.03).pdf',
#  '[NAVER] 지속가능경영보고서 등 관련사항(자율공시) 기타공개첨부서류 (2023.07.03) (1).pdf',
#  '[NAVER] 지속가능경영보고서 등 관련사항(자율공시) 기타공개첨부서류 (2023.07.03).pdf',
#  '[SK이노베이션] 지속가능경영보고서 등 관련사항(자율공시) 기타공개첨부서류 (2023.07.14).pdf',
#  '[SK하이닉스] 지속가능경영보고서 등 관련사항(자율공시) [정정]기타공개첨부서류 (2023.08.04).pdf',
# ...

# %%
#for name in folderlist:
#    loader = PyPDFLoader(f"C:/Users/user/Desktop/LLM/PDFs/{name}")
#    pages_new = loader.load_and_split(text_splitter)    
#    _ = vector_index.add_documents(pages_new)
#    vector_index.persist()

# %%
for name in tqdm(folderlist, desc="파일 처리 중"):  
    loader = PyPDFLoader(f"C:/Users/user/Desktop/LLM/PDFs/{name}")
    pages_new = loader.load_and_split(text_splitter)    
    _ = vector_index.add_documents(pages_new)
    vector_index.persist()
# Out:
# ...
# 파일 처리 중: 100%|██████████| 33/33 [19:55<00:00, 36.22s/it]

# %%
#text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=200)
#pages = loader.load_and_split(text_splitter)

# %%
pages_new
# Out:
# [Document(page_content='WE BREW HEALTHY TOMORROW\n모두가 꿈꾸는 건강한 내일을 빚습니다\n하이트진로 2023 지속가능경영보고서HITEJINRO \nSUSTAINABILITY \nREPORT 2023', metadata={'source': 'C:/Users/user/Desktop/LLM/PDFs/하이트진로 2023 지속가능경영보고서_국문.pdf', 'page': 0}),
#  Document(page_content='We Brew Healthy Tomorrow\n모두가 꿈꾸는 건강한 내일을 빚습니다\nCover Story\n하이트진로의 첫 지속가능경영보고서의 표지는 모든 이해관계자들이 함께 모여 협력을 이루는 모습을 표현하였습니다.\n작은 물방울이 모여 커다란 물방울을 만들고 물방울이 밖을 향해 퍼져가는 패턴은 \n협력의 결과가 사회로 확산되는 하이트진로의 바람이 표현된 것입니다.Tomorrow with HITEJINRO\nMouse hover 상단의 패턴을 마우스로 클릭해 보세요.', metadata={'source': 'C:/Users/user/Desktop/LLM/PDFs/하이트진로 2023 지속가능경영보고서_국문.pdf', 'page': 1}),
# ...

# %%
####pages_new를 jason으로 변환 ----->pro3.ipynb로 넘어감

####################################################################################################################################
import json

# Document 객체 리스트를 JSON 형식으로 변환하기 위한 함수
def document_to_json(documents):
    # Document 객체의 내용을 딕셔너리 리스트로 변환
    docs_list = [
        {"page_content": doc.page_content, "metadata": doc.metadata}
        for doc in documents
    ]
    return docs_list

# pages_new 데이터를 JSON 파일로 저장
with open('pages_new.json', 'w', encoding='utf-8') as file:
    json.dump(document_to_json(pages_new), file, ensure_ascii=False, indent=4)
######################################################################################################################################

# %%
directory = 'index_store'
#vector_index = Chroma.from_documents(pages, OpenAIEmbeddings(), persist_directory=directory)
vector_index = Chroma.from_documents(pages_new, OpenAIEmbeddings(), persist_directory=directory)
vector_index.persist() # actually the Chroma client automatically persists the indexes when it is disposed - however better save then sorry :-)

# %%
retriever = vector_index.as_retriever(search_type="similarity", search_kwargs={"k":6})
# create the chain for allowing us to chat with the document
qa_interface = RetrievalQA.from_chain_type(llm=ChatOpenAI(), chain_type="stuff", retriever=retriever, return_source_documents=True)
# Out:
# c:\Users\user\anaconda3\envs\nlp1\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
qa_interface("미래에셋의 esg경영을 알려줘")
# Out:
# c:\Users\user\anaconda3\envs\nlp1\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# {'query': '미래에셋의 esg경영을 알려줘',
#  'result': '미래에셋은 ESG(환경, 사회, 지배구조) 경영을 전략적으로 추구하고 있습니다. 회사는 친환경 투자의 안정적인 재원 조달을 위해 ESG 채권의 발행을 늘리고 있으며, 녹색 프로젝트와 사회적 가치 활동을 연계한 지속 가능채권을 검토하고 있습니다. 또한, K-택소노미를 반영한 "ESG 채권 관리체계"를 운영하고 있으며, 발행기준을 강화하고 사전 인증 및 사후 보고에 대한 외부 검증 의무화로 채권 발행의 건전성을 높이고 있습니다. 미래에셋은 녹색채권을 통해 자금을 조달하여 환경개선 프로젝트를 진행하고, 해당 프로젝트는 "매우 우량"한 수준으로 평가받았습니다. 또한, 회사는 ESG 경영을 전사적으로 내재화하기 위해 ESG협의체와 ESG 거버넌스지속가능경영팀을 운영하고 있습니다. ESG협의체는 각 분과별 ESG 추진 방향 및 계획을 논의하고, 리스크 저감 및 성과 개선 활동을 수행하며, 성과 정보를 공유하고 있습니다. ESG 거버넌스지속가능경영팀은 ESG 경영체계 구축, 조직 내재화, 협력체계 구축, 대외 공시 및 소통 등을 담당하고 있습니다.',
# ...

# %%
qa_interface("신세계의 esg경영을 알려줘")
# Out:
# {'query': '신세계의 esg경영을 알려줘',
#  'result': "신세계는 20여 년 전부터 '윤리경영'을 바탕으로 ESG(환경, 사회, 지배구조) 경영을 실천하고 있습니다. 이를 통해 기후변화 대응을 위한 자원순환, 온실가스 감축 등의 '환경경영'을 실천하고 있습니다. 또한, 지역사회와의 나눔을 실천하고 사회적 책임을 이행하며, '투명하고 공정한 경영'을 추구하고 있습니다. 신세계는 명확한 목표와 전략을 바탕으로 다양한 과제를 구체화하여 ESG 경영을 실천하고 있습니다. 최근에는 ESG 보고서를 발행하여 이해관계자들과 함께 결과물을 공유하고 있습니다. 또한, 신세계는 ESG 관리를 위해 ESG위원회와 ESG추진사무국을 운영하고 있으며, 대표이사의 성과지표에도 ESG 활동 성과를 반영하고 있습니다.",
#  'source_documents': [Document(page_content='신세계는 20여 년 전 선포한 ‘윤리경영’을 바탕으로, ESG 경영을 꾸준히 실천해 오고 있습니다. 기후변화 대응을 위한 자원순환, 온실가스 \n감축 등의 ‘환경경영’으로부터, 나눔을 실천하고 지역사회와 같이 성장하는 ‘사회적 책임의 이행’, 그리고 ‘투명하고 공정한 경영’에 이르기까지, 명확한 목표와 전략 아래 여러 과제를 구체화해 나가고 있습니다. 최근에 진행 중인 이러한 노력을 담아 작년에 이에 두 번째로 ESG 보고서를 발행하게 되었습니다. 이해관계자 여러분들과 함께 금번 결과물들을 공감할 수 있게 되어 더없이 기쁘게 생각합니다.\n불확실한 경영 환경 속에서 기업은 저마다의 방식으로 어려움을 극복해 나가고 있습니다. 신세계는 항상 고객의 변화하는 라이프스타일과', metadata={'page': 9, 'source': 'C:/Users/user/Desktop/LLM/PDFs/2022 신세계 ESG 보고서.pdf'}),
# ...

# %%
qa_interface("한국지역난방공사의 재생에너지 노력은?")
# Out:
# {'query': '한국지역난방공사의 재생에너지 노력은?',
#  'result': '한국지역난방공사는 재생에너지 사업에도 많은 관심을 가지고 있습니다. 해당 공사는 신재생에너지 사업을 주요사업 중 하나로 포함하고 있으며, 깨끗하고 친환경적인 에너지 생산을 위해 노력하고 있습니다. 그러나 정확한 세부 내용은 제공되지 않았으므로 더 자세한 정보는 공식 웹사이트나 관련 보도 자료를 참고하시는 것이 좋습니다.',
#  'source_documents': [Document(page_content='한국지역난방공사는 깨끗하고 효율적인 집단에너지 사업을 통하여 국민의 생활과 행복한 삶을  \n지원하고 있습니다. 공사는 지역 난방·냉방 사업과 전력사업의 경쟁력을 바탕으로 종합에너지사로  \n거듭나고 있습니다. 국민의 든든한 에너지 파트너인 공사는 지속가능한 성장으로 세계 초일류  \n에너지 전문기업으로 나아가겠습니다.주요사업02\n집단에너지 살펴보기\n전력사업\n신재생에너지 사업지역 난방·냉방 사업12\n기업 현황 소개 주요사업 ESG 체계 ESG 경영성과 부록', metadata={'page': 11, 'source': 'C:/Users/user/Desktop/LLM/PDFs/2022 한국지역난방공사 ESG보고서.pdf'}),
# ...

# %%
qa_interface("한진칼의esg 노력은?")
# Out:
# {'query': '한진칼의esg 노력은?',
#  'result': '한진칼은 ESG (환경, 사회, 지배구조) 영역에서 체계적인 거버넌스를 구축하고 지속가능한 경영을 추구하기 위해 노력하고 있습니다. 회사는 ESG 관련 정책 및 이슈를 이사회 차원에서 검토할 수 있도록 ESG 경영위원회를 설치하고, 이사회로부터 회사의 ESG 관련 경영사항에 대한 심의 권한을 위임받았습니다. 이를 통해 이사회와 ESG 경영위원회는 주요 ESG 현안과 이슈를 파악하고 결정할 수 있도록 지원 조직을 통해 활발한 지원을 제공하고 있습니다. 또한, 한진칼은 다양한 사회적 이슈에 대한 고민을 공유하기 위해 주요 상장 계열회사로 구성된 ESG 실무협의체를 운영하고 있습니다. 이를 통해 그룹 내 각 회사들이 함께 ESG 현안을 고민하고 해결해 나갈 수 있도록 하고 있습니다. 이러한 노력을 통해 한진칼은 지속가능한 경영을 추구하고 ESG 선도기업으로서의 역할을 수행하고 있습니다.',
# ...

# %%
qa_interface("한진칼과 한화생명의 esg전략을 비교해?")
# Out:
# {'query': '한진칼과 한화생명의 esg전략을 비교해?',
#  'result': '제가 아는 한으로는 한진칼과 한화생명의 ESG 전략에 대한 구체적인 정보를 제공할 수 없습니다. 이에 대한 정보는 해당 기업들의 공식 웹사이트나 보고서를 참조하시거나, 관련된 뉴스 기사나 리서치 보고서를 찾아보시는 것을 추천드립니다.',
#  'source_documents': [Document(page_content='제안을 드리고 싶습니다. 주니어보드는 주로 실무를 담당하는 직급으로 \n이루어져 있어 대외 환경변화를 민감하게 느낀다는 장점이 있지만, 이를  \n적용 가능한 부분은 제한적입니다. 따라서 경험과 네트워크가 풍부한  \n시니어와 함께 지속가능성을 논의할 기회가 많아진다면, 주니어의 실무  \n감각에 시니어의 전체적인 조감 능력이 더해지는 시너지를 기대할 수  \n있을 것이라 생각합니다. 마지막으로, 본 보고서를 통하여 외부 이해  \n관계자는 물론 공사의 직원들도 ESG 경영을 충분히 이해하고 그 필요성에  \n깊이 공감하는 기회가 되기를 바랍니다.한국지역난방공사는 주요사업 자체에 에너지 절약, 온실가스 감축, 대기  \n오염 저감효과가 내재되어 있으며 미활용 에너지 및 신재생에너지를  \n활용하는 사업을 계속해서 확장하고 있습니다. 이산화탄소를 활용한  \n기술을 자체적으로 연구·개발하고, 미래전략으로 수소 경제에 투자하는  \n등 환경경영을 앞장서서 추진하고 있습니다. 사업 자체가 친환경적인', metadata={'page': 26, 'source': 'C:/Users/user/Desktop/LLM/PDFs/2022 한국지역난방공사 ESG보고서.pdf'}),
# ...

# %%
#jupyter nbconvert --to script a.ipynb
#from a import 함수명

# %%
#
